# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
a=np.load('./res/p0_0.npy')

# %%
a[64,64,64]=0
plt.imshow(a[90,:,:])
plt.colorbar()

# %%
a
# Out:
# array([[[ 1.0509641e-03,  1.1284301e-03,  1.0044272e-03, ...,
#           1.3617083e-04,  3.8818925e-04,  2.0290060e-04],
#         [ 1.1284301e-03,  1.0271063e-03,  1.1124994e-03, ...,
#           3.2796629e-04,  0.0000000e+00,  3.8818925e-04],
#         [ 1.0044272e-03,  1.1124994e-03,  9.4830978e-04, ...,
#           6.8530149e-05,  3.2796629e-04,  1.3617083e-04],
#         ...,
#         [-3.6234819e-04, -4.0443658e-04, -3.3981143e-04, ...,
#           1.8367983e-04,  2.0286853e-04,  1.9071621e-04],
#         [-4.0995874e-04, -3.4586029e-04, -4.0443658e-04, ...,
#           2.0286853e-04,  1.7643982e-04,  2.0393370e-04],
#         [-3.8081509e-04, -4.0995874e-04, -3.6234819e-04, ...,
#           1.9071621e-04,  2.0393370e-04,  1.9630614e-04]],
#
#        [[ 1.1284301e-03,  1.0271063e-03,  1.1124994e-03, ...,
#           3.2796629e-04,  0.0000000e+00,  3.8818925e-04],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
# ...

# %%
plt.imshow(a[:,0,:])
plt.colorbar()
