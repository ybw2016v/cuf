# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
a=np.load('./res/p0_17.npy')

# %%
a[200,200]=0
# a[0:100,:]=100
plt.imshow(a)
plt.colorbar()

# %%
a=np.load('./res/p0_20.npy')

# %%
a[200,200]=0
# a[0:100,:]=100
plt.imshow(a[:,:])
plt.colorbar()

# %%
a=np.load('./res/p0_7.npy')

# %%
a[200,200]=0
# a[0:100,:]=100
plt.imshow(a)
plt.colorbar()

# %%
a=np.load('./res/p0_19.npy')
plt.plot(a[0,:])
